# %% [markdown]
# ### 20220704 수업 실습

# %%
#1-1
import pandas as pd
import numpy as np 


weather = pd.read_csv("data/weather.csv",encoding='cp949',index_col=["일시"])
print(weather.shape)
print(weather.head(3))
print(weather.tail(3))
# Out:
# (3653, 3)
#             평균기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)
# 일시
# 2010-08-01      28.7         8.3         3.4
# 2010-08-02      25.2         8.7         3.8
# 2010-08-03      22.1         6.3         2.9
#             평균기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)
# 일시
# 2020-07-29      21.6         3.2         1.0
# 2020-07-30      22.9         9.7         2.4
# 2020-07-31      25.7         4.8         2.5

# %%
#1-2
print(weather.loc['2015-06-06'])
# Out:
# 평균기온(°C)      16.6
# 최대 풍속(m/s)     4.4
# 평균 풍속(m/s)     1.9
# Name: 2015-06-06, dtype: float64

# %%
#1-3
weather['평균기온(°C)'].max()
# Out:
# 31.3

# %%
#1-4
weather[weather['평균기온(°C)']== weather['평균기온(°C)'].max()]
# Out:
#             평균기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)
# 일시
# 2013-08-08      31.3         7.8         4.6

# %%
#1-5
weather[weather['평균기온(°C)'] >= 30.0]
# Out:
#             평균기온(°C)  최대 풍속(m/s)  평균 풍속(m/s)
# 일시
# 2013-08-08      31.3         7.8         4.6
# 2013-08-09      30.6         9.9         6.4
# 2013-08-10      30.6         7.4         3.8
# 2018-07-23      30.5         6.5         1.6
# 2018-08-04      30.3         5.8         3.0

# %%
#2
P = pd.DataFrame({
    'name' : ['A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'horse power' : [130, 250, 190, 300, 210, 220, 170],
    'weight' : [1.9, 2.6, 2.2, 2.9, 2.4, 2.3, 2.2],
    'efficiency': [16.3, 10.2, 11.1, 7.1, 12.1, 13.2, 14.2] })
P
# Out:
#   name  horse power  weight  efficiency
# 0    A          130     1.9        16.3
# 1    B          250     2.6        10.2
# 2    C          190     2.2        11.1
# 3    D          300     2.9         7.1
# 4    E          210     2.4        12.1
# 5    F          220     2.3        13.2
# 6    G          170     2.2        14.2

# %%
#2-1
P = P.set_index('name')
P.head(3)
# Out:
#       horse power  weight  efficiency
# name
# A             130     1.9        16.3
# B             250     2.6        10.2
# C             190     2.2        11.1

# %%
#2-2
P.sort_values(by='horse power',ascending=False).head(1)
# Out:
#       horse power  weight  efficiency
# name
# D             300     2.9         7.1

# %%
#2-3
P['hp x mile']=P['horse power']*P['efficiency']
P.sort_values(by='hp x mile',ascending=False).head(1)
#print(df[df[hpxmile]==df['hp x mile'].max()])
# Out:
#       horse power  weight  efficiency  hp x mile
# name
# F             220     2.3        13.2     2904.0

# %%
#3
#3-1
Q = pd.DataFrame({
    'name':['A','B','C','D'],
    'horse power':[120,220,120,200],
    'weight':[1.9,2.1,1.5,2.9],
    'efficiency':[18.3,19.2,21.5,17.3]
})
Q
# Out:
#   name  horse power  weight  efficiency
# 0    A          120     1.9        18.3
# 1    B          220     2.1        19.2
# 2    C          120     1.5        21.5
# 3    D          200     2.9        17.3

# %%
#3-2
result = pd.concat([P,Q], ignore_index=True)
result=result .set_index('name')
result
# Out:
#       horse power  weight  efficiency
# name
# A             130     1.9        16.3
# B             250     2.6        10.2
# C             190     2.2        11.1
# D             300     2.9         7.1
# E             210     2.4        12.1
# F             220     2.3        13.2
# G             170     2.2        14.2
# A             120     1.9        18.3
# B             220     2.1        19.2
# C             120     1.5        21.5
# D             200     2.9        17.3

# %%
#3-4
result['com']= 'P'
result
# Out:
#       horse power  weight  efficiency com
# name
# A             130     1.9        16.3   P
# B             250     2.6        10.2   P
# C             190     2.2        11.1   P
# D             300     2.9         7.1   P
# E             210     2.4        12.1   P
# F             220     2.3        13.2   P
# G             170     2.2        14.2   P
# A             120     1.9        18.3   P
# B             220     2.1        19.2   P
# C             120     1.5        21.5   P
# D             200     2.9        17.3   P

# %%
result.iloc[7:11,3:4]='Q'
result
# Out:
#       horse power  weight  efficiency com
# name
# A             130     1.9        16.3   P
# B             250     2.6        10.2   P
# C             190     2.2        11.1   P
# D             300     2.9         7.1   P
# E             210     2.4        12.1   P
# F             220     2.3        13.2   P
# G             170     2.2        14.2   P
# A             120     1.9        18.3   Q
# B             220     2.1        19.2   Q
# C             120     1.5        21.5   Q
# D             200     2.9        17.3   Q

# %%
#3-5
result['hp x mile']=result['horse power']*result['efficiency']
result
# Out:
#       horse power  weight  efficiency com  hp x mile
# name
# A             130     1.9        16.3   P     2119.0
# B             250     2.6        10.2   P     2550.0
# C             190     2.2        11.1   P     2109.0
# D             300     2.9         7.1   P     2130.0
# E             210     2.4        12.1   P     2541.0
# F             220     2.3        13.2   P     2904.0
# G             170     2.2        14.2   P     2414.0
# A             120     1.9        18.3   Q     2196.0
# B             220     2.1        19.2   Q     4224.0
# C             120     1.5        21.5   Q     2580.0
# D             200     2.9        17.3   Q     3460.0

# %%
result.groupby(["com"])["hp x mile"].mean()
# Out:
# com
# P    2395.285714
# Q    3115.000000
# Name: hp x mile, dtype: float64

# %% [markdown]
# ### 수업 내용

# %%
titanic = pd.read_csv('data/titanic.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.loc[titanic["Age"]<20,"Name"]
# Out:
# 7            Palsson, Master. Gosta Leonard
# 9       Nasser, Mrs. Nicholas (Adele Achem)
# 10          Sandstrom, Miss. Marguerite Rut
# 14     Vestrom, Miss. Hulda Amanda Adolfina
# 16                     Rice, Master. Eugene
#                        ...
# 855              Aks, Mrs. Sam (Leah Rosen)
# 869         Johnson, Master. Harold Theodor
# 875        Najib, Miss. Adele Kiamie "Jane"
# 877                    Petroff, Mr. Nedelio
# 887            Graham, Miss. Margaret Edith
# Name: Name, Length: 164, dtype: object

# %%
titanic.iloc[20:23,5:7]
# Out:
#      Age  SibSp
# 20  35.0      0
# 21  34.0      0
# 22  15.0      0

# %%
titanic.sort_values(by='Age').head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 78            79         1       2    Caldwell, Master. Alden Gates    male
#
#       Age  SibSp  Parch  Ticket     Fare Cabin Embarked
# 803  0.42      0      1    2625   8.5167   NaN        C
# 755  0.67      1      1  250649  14.5000   NaN        S
# 644  0.75      2      1    2666  19.2583   NaN        C
# 469  0.75      2      1    2666  19.2583   NaN        C
# 78   0.83      0      2  248738  29.0000   NaN        S

# %%
titanic.sort_values(by=['Pclass','Age'],ascending=False).head(10)
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 851          852         0       3               Svensson, Mr. Johan    male
# 116          117         0       3              Connors, Mr. Patrick    male
# 280          281         0       3                  Duane, Mr. Frank    male
# 483          484         1       3            Turkula, Mrs. (Hedwig)  female
# 326          327         0       3         Nysveen, Mr. Johan Hansen    male
# 94            95         0       3                 Coxon, Mr. Daniel    male
# 152          153         0       3                  Meo, Mr. Alfonzo    male
# 222          223         0       3           Green, Mr. George Henry    male
# 406          407         0       3  Widegren, Mr. Carl/Charles Peter    male
# 631          632         0       3       Lundahl, Mr. Johan Svensson    male
#
#       Age  SibSp  Parch      Ticket    Fare Cabin Embarked
# 851  74.0      0      0      347060  7.7750   NaN        S
# ...

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic[["Age","Fare"]].median()
# Out:
# Age     28.0000
# Fare    14.4542
# dtype: float64

# %%
titanic[["Sex","Age"]].groupby("Sex").mean()
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby(["Sex","Pclass"])["Fare"].mean()
# Out:
# Sex     Pclass
# female  1         106.125798
#         2          21.970121
#         3          16.118810
# male    1          67.226127
#         2          19.741782
#         3          12.661633
# Name: Fare, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
countries = pd.read_csv('data/countries.csv')
countries['density']=countries['population']/countries['area']
countries
# Out:
#   code country      area     capital  population     density
# 0   KR   Korea     98480       Seoul    48422644  491.700284
# 1   US     USA   9629091  Washington   310232863   32.218292
# 2   JP   Japan    377835       Tokyo   127288000  336.887795
# 3   CN   China   9596960     Beijing  1330044000  138.590137
# 4   RU  Russia  17100000      Moscow   140702000    8.228187

# %%
countries["population"]
# Out:
# 0      48422644
# 1     310232863
# 2     127288000
# 3    1330044000
# 4     140702000
# Name: population, dtype: int64

# %%
countries[["population","area"]].sort_values(by="area")
# Out:
#    population      area
# 0    48422644     98480
# 2   127288000    377835
# 3  1330044000   9596960
# 1   310232863   9629091
# 4   140702000  17100000

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.DataFrame({
    'name':['Kim','Lee','Park','Choi','Hong','Chung','Jang'],
    'age':[22,26,78,17,46,32,21],
    'city':['Seoul','Busan','Seoul','Busan','Seoul','Daejun','Daejun'],
    'children':[2,3,0,1,3,4,3],
    'pets':[0,1,0,2,2,0,3]
})

# %%
df.plot(kind='line', x='city', y='pets', color='lightblue')
plt.show()

# %%
ax = plt.gca() #gca(): get current axis

df.plot(kind='line',x='name',y='children',ax=ax)
df.plot(kind='line',x='name',y='pets', color='pink', ax=ax)

plt.show()

# %%
df.plot(kind="bar",x="name",y="age")
plt.show()

# %%
df[["age"]].plot(kind='hist',bins=[0,20,40,60,80,100],rwidth=0.8)
plt.show()

# %%
seoul = pd.read_csv("data/seoul.csv",'r',encoding='cp949')
print(seoul.shape)
seoul.head()
# Out:
# (40221, 1)
# /Users/seonghyeonma/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    날짜,지점,평균기온(℃),최저기온(℃),최고기온(℃)
# 0   1907-10-01,108,13.5,7.9,20.7
# 1     1907-10-02,108,16.2,7.9,22
# 2  1907-10-03,108,16.2,13.1,21.3
# 3    1907-10-04,108,16.5,11.2,22
# 4  1907-10-05,108,17.6,10.9,25.4

# %%
import csv 
f=open('data/seoul.csv','r',encoding='cp949')
data = csv.reader(f)
for row in data:
    print(row)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
# ['1907-10-01', '108', '13.5', '7.9', '20.7']
# ['1907-10-02', '108', '16.2', '7.9', '22']
# ['1907-10-03', '108', '16.2', '13.1', '21.3']
# ['1907-10-04', '108', '16.5', '11.2', '22']
# ['1907-10-05', '108', '17.6', '10.9', '25.4']
# ['1907-10-06', '108', '13', '11.2', '21.3']
# ['1907-10-07', '108', '11.3', '6.3', '16.1']
# ['1907-10-08', '108', '8.9', '3.9', '14.9']
# ['1907-10-09', '108', '11.6', '3.8', '21.1']
# ['1907-10-10', '108', '14.2', '6.4', '24.1']
# ['1907-10-11', '108', '15.4', '10.1', '20.4']
# ['1907-10-12', '108', '13.9', '11.1', '17.4']
# ['1907-10-13', '108', '13.8', '8.3', '21.3']
# ['1907-10-14', '108', '13', '6.1', '20.6']
# ['1907-10-15', '108', '13.1', '5.7', '20.9']
# ['1907-10-16', '108', '14.1', '8.2', '20.2']
# ['1907-10-17', '108', '16.4', '10.3', '21.6']
# ['1907-10-18', '108', '14.3', '9.8', '20.9']
# ['1907-10-19', '108', '13.9', '6.7', '21.3']
# ['1907-10-20', '108', '18.3', '12.4', '22.7']
# ...

# %%
import csv 
f=open('data/seoul.csv','r',encoding='cp949')
data = csv.reader(f)
header = next(data)
print(header)
f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']

# %%
import csv 
f=open('data/seoul.csv',encoding='cp949')
data = csv.reader(f)
header = next(data)
for row in data:
    row[-1]=float(row[-1])
    print(row)
f.close()
# Out:
# ['1907-10-01', '108', '13.5', '7.9', 20.7]
# ['1907-10-02', '108', '16.2', '7.9', 22.0]
# ['1907-10-03', '108', '16.2', '13.1', 21.3]
# ['1907-10-04', '108', '16.5', '11.2', 22.0]
# ['1907-10-05', '108', '17.6', '10.9', 25.4]
# ['1907-10-06', '108', '13', '11.2', 21.3]
# ['1907-10-07', '108', '11.3', '6.3', 16.1]
# ['1907-10-08', '108', '8.9', '3.9', 14.9]
# ['1907-10-09', '108', '11.6', '3.8', 21.1]
# ['1907-10-10', '108', '14.2', '6.4', 24.1]
# ['1907-10-11', '108', '15.4', '10.1', 20.4]
# ['1907-10-12', '108', '13.9', '11.1', 17.4]
# ['1907-10-13', '108', '13.8', '8.3', 21.3]
# ['1907-10-14', '108', '13', '6.1', 20.6]
# ['1907-10-15', '108', '13.1', '5.7', 20.9]
# ['1907-10-16', '108', '14.1', '8.2', 20.2]
# ['1907-10-17', '108', '16.4', '10.3', 21.6]
# ['1907-10-18', '108', '14.3', '9.8', 20.9]
# ['1907-10-19', '108', '13.9', '6.7', 21.3]
# ['1907-10-20', '108', '18.3', '12.4', 22.7]
# ['1907-10-21', '108', '15.2', '10.7', 19.9]
# ['1907-10-22', '108', '15.4', '12.1', 19.6]
# ...

# %%
import csv 
f=open('data/seoul.csv',encoding='cp949')
data=csv.reader(f)
max_temp=999
max_date=""
    for row in data:
        if row[-1]=='':
        row[-1]=-999
        row[-1]=float(row[-1])
    if max_temp<row[-1]:
        max_date = row[0]
        max_temp=row[-1]
# Out:
#   File "/var/folders/nz/160bjb610xj3r4wkpjkgnw940000gn/T/ipykernel_99183/1942218838.py", line 6
#     for row in data:
#     ^
# IndentationError: unexpected indent

# %%
import csv 
f=open('data/seoul.csv',encoding='cp949')
data=csv.reader(f)
next(data)
result=[]

for row in data:
    if row[-1] != '':
        result.append(float(row[-1]))
print(result)
# Out:
# [20.7, 22.0, 21.3, 22.0, 25.4, 21.3, 16.1, 14.9, 21.1, 24.1, 20.4, 17.4, 21.3, 20.6, 20.9, 20.2, 21.6, 20.9, 21.3, 22.7, 19.9, 19.6, 16.3, 17.1, 18.7, 18.2, 20.7, 19.6, 20.0, 20.1, 20.3, 21.3, 21.1, 11.1, 13.6, 17.0, 18.1, 12.4, 9.4, 11.9, 13.2, 13.4, 14.9, 16.4, 15.2, 17.6, 12.6, 11.7, 6.7, 4.3, 7.1, 6.2, 11.2, 9.9, 5.9, -0.7, 1.5, 1.9, 2.0, 2.9, -2.4, 1.4, 3.4, 6.1, 1.3, 2.6, 5.8, 1.9, 6.6, 8.1, 4.3, 0.6, 3.8, 9.0, 6.4, -5.1, -2.4, -2.1, -0.4, -0.2, 1.9, -8.1, -10.2, -9.4, 0.9, 6.8, 6.4, -0.7, -1.9, -4.4, -6.1, -2.1, -1.3, -3.0, -2.9, -1.7, -0.1, 2.9, -1.2, -0.9, 2.0, 3.3, 4.8, 4.5, 4.7, 0.1, 0.9, -4.5, -3.6, 2.8, 2.8, 2.3, -6.1, -5.1, -2.7, 0.1, 0.3, -0.6, 0.0, -1.3, 0.8, 0.8, 6.2, 1.6, -0.2, -5.4, -4.1, -5.5, -5.7, -3.7, 1.3, -4.1, -2.5, -2.8, -1.2, 1.3, 2.3, 2.0, -1.4, -1.6, 0.3, 5.5, 7.3, 5.1, 5.4, 2.7, 1.7, 0.8, 4.1, 8.4, 6.3, 5.6, 4.0, 0.1, 4.9, 4.0, 7.9, 7.9, 2.2, 1.9, 1.5, 1.5, 1.8, 2.6, 3.8, 6.7, 11.8, 13.5, 15.7, 10.7, 7.9, 4.3, 6.0, 12.5, 17.0, 14.7, 11.4, 7.4, 8.0, 15.5
# ...

# %%
import matplotlib.pyplot as plt

plt.plot(result,'r')
plt.show()

# %%
import csv
import matplotlib.pyplot as plt
 
in
 
aug = []                          # 8월의 최고 기온 값을 저장할 aug 리스트 생성
jan = []                          # 1월의 최고 기온 값을 저장할 jan 리스트 생성

for row in data :
    month = row[0].split('-')[1]  # -로 구분된 값 중 2번째 값을 month에 저장
    if row[-1] != '' :
        if month == '08':               # 8월달이라면
            aug.append(float(row[-1]))  # aug 리스트에 최고 기온 값 추가
        if month == '01':               # 1월달이라면
            jan.append(float(row[-1]))  # jan 리스트에 최고 기온 값 추가

plt.hist(aug, bins=100, color ='r', label='Aug')
plt.hist(jan, bins=100, color ='b', label='Jan')
plt.legend()
plt.show()

# %%
s = "hello python"
print(s.split())
# Out:
# ['hello', 'python']

# %%
date ='1907-10-10'
print(date.split('-'))
# Out:
# ['1907', '10', '10']

# %%
print(date.split('-')[0])
print(date.split('-')[1])
print(date.split('-')[2])
# Out:
# 1907
# 10
# 10

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('data/seoul.csv',encoding='cp949')
data = csv.reader(f)
next(data)
result=[]


for row in data:
    if row[-1]!="":
        if row[0].split('-')[1]=='08':
            result.append(float(row[-1]))

plt.plot(result,'hotpink')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('data/seoul.csv',encoding='cp949')
data = csv.reader(f)
next(data)
result=[]

for row in data:
    if row[-1]!="":
        if row[0].split('-')[1]=='02'and row[0].split('-')[2]=='14':
            result.append(float(row[-1]))

plt.plot(result,'b')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
import csv
import matplotlib.pyplot as plt
 
f = open('data/seoul.csv',encoding='cp949')
data = csv.reader(f)
next(data)
high=[]
low=[]


for row in data:
    if row[-1]!="" and row[-2]!='':
        if 1983<=int(row[0].split('-')[0]):
            if row[0].split('-')[1]=='02'and row[0].split('-')[2]=='14':
                high.append(float(row[-1]))
                low.append(float(row[-2]))

plt.plot(high,'b')
plt.plot(low,'r')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
